# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
import pandas as pd



# Input sentence
sentence = "I am very interested in Applied AI"

# Tokenize sentence
words = word_tokenize(sentence)

# Create lists for DataFrame
word_list = []
synonym_list = []
antonym_list = []

for word in words:
    synonyms = set()
    antonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
    
    if synonyms or antonyms:  # Include only meaningful words
        word_list.append(word)
        synonym_list.append(', '.join(list(synonyms)[:5]))  # Limit to 5 for readability
        antonym_list.append(', '.join(list(antonyms)[:5]))

# Display results as a table
df = pd.DataFrame({
    'Word': word_list,
    'Synonyms (Top 5)': synonym_list,
    'Antonyms (Top 5)': antonym_list
})

print("Sentence:", sentence)
print("\nWord-wise Synonyms and Antonyms:\n")
display(df)
print("Done By Junaid Sardar S")
# Out:
# Sentence: I am very interested in Applied AI
#
# Word-wise Synonyms and Antonyms:
#          Word                                   Synonyms (Top 5)  \
# 0           I                     1, i, I, ace, atomic_number_53
# 1          am               embody, MA, be, Am, atomic_number_95
# 2        very        identical, rattling, very, selfsame, really
# 3  interested    concern, interest, matter_to, concerned, occupy
# 4          in      Indiana, indium, in, atomic_number_49, inward
# 5     Applied        apply, go_for, hold, practice, lend_oneself
# 6          AI  artificial_intelligence, AI, Army_Intelligence...
#
#             Antonyms (Top 5)
# 0
# 1                     differ
# 2
# 3         bore, uninterested
# 4
# 5  defy, exempt, theoretical
# 6
# Done By Junaid Sardar S
